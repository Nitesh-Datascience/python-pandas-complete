# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##*Data Import*

# %%
df = pd.read_csv('ai_job_trends_dataset.csv')
# From CSV file

#pd.read_excel('file.xius', sheet name Sheet1")
# From Excel
#pd.read_sql(query, connection) 
# From SQL database
#pd.read_son('file.json') 
# From JSON file
#pd.read_parquet('file.parquet') 
# From Parquet file (compressed)

# %%
df
# Out:
#                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 0            Moderate             42109.76    Master’s Degree
# ...

# %%
 #*Data Selection*

# %%
print(df.columns)   # Single column
# Out:
# Index(['Job Title', 'Industry', 'Job Status', 'AI Impact Level',
#        'Median Salary (USD)', 'Required Education',
#        'Experience Required (Years)', 'Job Openings (2024)',
#        'Projected Openings (2030)', 'Remote Work Ratio (%)',
#        'Automation Risk (%)', 'Location', 'Gender Diversity (%)',
#        'Bonus Salary'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                Job Title       Industry  Job Status AI Impact Level  \
# 0     Investment analyst             IT  Increasing        Moderate
# 1  Journalist, newspaper  Manufacturing  Increasing        Moderate
# 2      Financial planner        Finance  Increasing             Low
# 3        Legal secretary     Healthcare  Increasing            High
# 4  Aeronautical engineer             IT  Increasing             Low
#
#    Median Salary (USD) Required Education  Experience Required (Years)  \
# 0             42109.76    Master’s Degree                            5
# 1            132298.57    Master’s Degree                           15
# 2            143279.19  Bachelor’s Degree                            4
# 3             97576.13   Associate Degree                           15
# 4             60956.63    Master’s Degree                           13
#
#    Job Openings (2024)  Projected Openings (2030)  Remote Work Ratio (%)  \
# ...

# %%
df.tail(5)
# Out:
#                              Job Title       Industry  Job Status  \
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 29995        Moderate            142238.00                PhD
# 29996        Moderate            123107.50   Associate Degree
# 29997        Moderate             97305.51    Master’s Degree
# 29998        Moderate             95599.22        High School
# 29999             Low             65679.61        High School
#
#        Experience Required (Years)  Job Openings (2024)  \
# 29995                           16                 7816
# 29996                           19                 9358
# ...

# %%
df.describe()
# Out:
#        Median Salary (USD)  Experience Required (Years)  Job Openings (2024)  \
# count         30000.000000                 30000.000000         30000.000000
# mean          90119.965639                    10.051433          5039.640833
# std           34412.013953                     6.060678          2861.009654
# min           30001.860000                     0.000000           100.000000
# 25%           60500.702500                     5.000000          2570.000000
# 50%           90274.115000                    10.000000          5034.000000
# 75%          119454.710000                    15.000000          7527.000000
# max          149998.500000                    20.000000         10000.000000
#
#        Projected Openings (2030)  Remote Work Ratio (%)  Automation Risk (%)  \
# count               30000.000000           30000.000000         30000.000000
# mean                 5074.218100              49.836431            50.154229
# ...

# %%
df.isnull()
# Out:
#        Job Title  Industry  Job Status  AI Impact Level  Median Salary (USD)  \
# 0          False     False       False            False                False
# 1          False     False       False            False                False
# 2          False     False       False            False                False
# 3          False     False       False            False                False
# 4          False     False       False            False                False
# ...          ...       ...         ...              ...                  ...
# 29995      False     False       False            False                False
# 29996      False     False       False            False                False
# 29997      False     False       False            False                False
# 29998      False     False       False            False                False
# 29999      False     False       False            False                False
#
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Industry', 'Job Status', 'AI Impact Level',
#        'Median Salary (USD)', 'Required Education',
#        'Experience Required (Years)', 'Job Openings (2024)',
#        'Projected Openings (2030)', 'Remote Work Ratio (%)',
#        'Automation Risk (%)', 'Location', 'Gender Diversity (%)',
#        'Bonus Salary'],
#       dtype='object')

# %%
df.reset_index()
# Out:
#        index                        Job Title       Industry  Job Status  \
# 0          0               Investment analyst             IT  Increasing
# 1          1            Journalist, newspaper  Manufacturing  Increasing
# 2          2                Financial planner        Finance  Increasing
# 3          3                  Legal secretary     Healthcare  Increasing
# 4          4            Aeronautical engineer             IT  Increasing
# ...      ...                              ...            ...         ...
# 29995  29995  Psychotherapist, dance movement      Education  Increasing
# 29996  29996         Scientist, water quality             IT  Decreasing
# 29997  29997                     Web designer  Manufacturing  Decreasing
# 29998  29998           Primary school teacher  Entertainment  Increasing
# 29999  29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# ...

# %%
df.drop_duplicates()
# Out:
#                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 0            Moderate             42109.76    Master’s Degree
# ...

# %%
df.shape
# Out:
# (30000, 14)

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Job Title                    30000 non-null  object
#  1   Industry                     30000 non-null  object
#  2   Job Status                   30000 non-null  object
#  3   AI Impact Level              30000 non-null  object
#  4   Median Salary (USD)          30000 non-null  float64
#  5   Required Education           30000 non-null  object
#  6   Experience Required (Years)  30000 non-null  int64
#  7   Job Openings (2024)          30000 non-null  int64
#  8   Projected Openings (2030)    30000 non-null  int64
#  9   Remote Work Ratio (%)        30000 non-null  float64
#  10  Automation Risk (%)          30000 non-null  float64
#  11  Location                     30000 non-null  object
#  12  Gender Diversity (%)         30000 non-null  float64
# ...

# %%
df.notnull()
# Out:
#        Job Title  Industry  Job Status  AI Impact Level  Median Salary (USD)  \
# 0           True      True        True             True                 True
# 1           True      True        True             True                 True
# 2           True      True        True             True                 True
# 3           True      True        True             True                 True
# 4           True      True        True             True                 True
# ...          ...       ...         ...              ...                  ...
# 29995       True      True        True             True                 True
# 29996       True      True        True             True                 True
# 29997       True      True        True             True                 True
# 29998       True      True        True             True                 True
# 29999       True      True        True             True                 True
#
# ...

# %%
df['AI Impact Level'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Moderate
# 1        Moderate
# 2             Low
# 3            High
# 4             Low
#            ...
# 29995    Moderate
# 29996    Moderate
# 29997    Moderate
# 29998    Moderate
# 29999         Low
# Name: AI Impact Level, Length: 30000, dtype: object>

# %%
df['AI Impact Level'].value_counts(dropna=False)
# Out:
# AI Impact Level
# Moderate    10042
# High        10005
# Low          9953
# Name: count, dtype: int64

# %%
df['Projected Openings (2030)'].mean()
# Out:
# 5074.2181

# %%
df['Job Openings (2024)'].mean()
# Out:
# 5039.640833333333

# %%
df.count()
# Out:
# Job Title                      30000
# Industry                       30000
# Job Status                     30000
# AI Impact Level                30000
# Median Salary (USD)            30000
# Required Education             30000
# Experience Required (Years)    30000
# Job Openings (2024)            30000
# Projected Openings (2030)      30000
# Remote Work Ratio (%)          30000
# Automation Risk (%)            30000
# Location                       30000
# Gender Diversity (%)           30000
# Bonus Salary                   30000
# dtype: int64

# %%
df.max()
# Out:
# Job Title                        Youth worker
# Industry                       Transportation
# Job Status                         Increasing
# AI Impact Level                      Moderate
# Median Salary (USD)                  149998.5
# Required Education                        PhD
# Experience Required (Years)                20
# Job Openings (2024)                     10000
# Projected Openings (2030)               10000
# Remote Work Ratio (%)                   100.0
# Automation Risk (%)                     99.99
# Location                                  USA
# Gender Diversity (%)                     80.0
# Bonus Salary                         14999.85
# dtype: object

# %%
df.min()
# Out:
# Job Title                      Academic librarian
# Industry                                Education
# Job Status                             Decreasing
# AI Impact Level                              High
# Median Salary (USD)                      30001.86
# Required Education               Associate Degree
# Experience Required (Years)                     0
# Job Openings (2024)                           100
# Projected Openings (2030)                     100
# Remote Work Ratio (%)                         0.0
# Automation Risk (%)                           0.0
# Location                                Australia
# Gender Diversity (%)                         20.0
# Bonus Salary                             3000.186
# dtype: object

# %%
df.median
# Out:
# <bound method DataFrame.median of                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 0            Moderate             42109.76    Master’s Degree
# ...

# %%
df.std
# Out:
# <bound method DataFrame.std of                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 0            Moderate             42109.76    Master’s Degree
# ...

# %%
df.loc()

# %%
df.head()
# Out:
#                Job Title       Industry  Job Status AI Impact Level  \
# 0     Investment analyst             IT  Increasing        Moderate
# 1  Journalist, newspaper  Manufacturing  Increasing        Moderate
# 2      Financial planner        Finance  Increasing             Low
# 3        Legal secretary     Healthcare  Increasing            High
# 4  Aeronautical engineer             IT  Increasing             Low
#
#    Median Salary (USD) Required Education  Experience Required (Years)  \
# 0             42109.76    Master’s Degree                            5
# 1            132298.57    Master’s Degree                           15
# 2            143279.19  Bachelor’s Degree                            4
# 3             97576.13   Associate Degree                           15
# 4             60956.63    Master’s Degree                           13
#
#    Job Openings (2024)  Projected Openings (2030)  Remote Work Ratio (%)  \
# ...

# %%
df.loc[:,["Job Title","AI Impact Level"]]
# Out:
#                              Job Title AI Impact Level
# 0                   Investment analyst        Moderate
# 1                Journalist, newspaper        Moderate
# 2                    Financial planner             Low
# 3                      Legal secretary            High
# 4                Aeronautical engineer             Low
# ...                                ...             ...
# 29995  Psychotherapist, dance movement        Moderate
# 29996         Scientist, water quality        Moderate
# 29997                     Web designer        Moderate
# 29998           Primary school teacher        Moderate
# 29999                Company secretary             Low
#
# [30000 rows x 2 columns]

# %%
df.loc[df["Experience Required (Years)"] < 5.00]
# Out:
#                              Job Title       Industry  Job Status  \
# 2                    Financial planner        Finance  Increasing
# 7                              Dentist  Entertainment  Decreasing
# 13     Runner, broadcasting/film/video     Healthcare  Decreasing
# 14                  Press photographer  Entertainment  Decreasing
# 15                Biochemist, clinical  Entertainment  Increasing
# ...                                ...            ...         ...
# 29965                Designer, textile         Retail  Decreasing
# 29969                    Buyer, retail  Entertainment  Decreasing
# 29983         Museum education officer        Finance  Increasing
# 29989           Surveyor, hydrographic         Retail  Increasing
# 29997                     Web designer  Manufacturing  Decreasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 2                 Low            143279.19  Bachelor’s Degree
# ...

# %%
df.loc[df["Experience Required (Years)"] > 5.00]
# Out:
#                              Job Title       Industry  Job Status  \
# 1                Journalist, newspaper  Manufacturing  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# 5                      Legal secretary      Education  Decreasing
# 6                  Surveyor, insurance  Manufacturing  Decreasing
# ...                                ...            ...         ...
# 29994        Commercial horticulturist  Entertainment  Decreasing
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 1            Moderate            132298.57    Master’s Degree
# ...

# %%
df.loc[:, ['Job Title', 'Median Salary (USD)']]
# Out:
#                              Job Title  Median Salary (USD)
# 0                   Investment analyst             42109.76
# 1                Journalist, newspaper            132298.57
# 2                    Financial planner            143279.19
# 3                      Legal secretary             97576.13
# 4                Aeronautical engineer             60956.63
# ...                                ...                  ...
# 29995  Psychotherapist, dance movement            142238.00
# 29996         Scientist, water quality            123107.50
# 29997                     Web designer             97305.51
# 29998           Primary school teacher             95599.22
# 29999                Company secretary             65679.61
#
# [30000 rows x 2 columns]

# %% [markdown]
#  #*Data Selection*

# %%
df[['Job Title', 'Median Salary (USD)', 'Location', 'Industry']]
# Single column
# Out:
#                              Job Title  Median Salary (USD)   Location  \
# 0                   Investment analyst             42109.76         UK
# 1                Journalist, newspaper            132298.57        USA
# 2                    Financial planner            143279.19     Canada
# 3                      Legal secretary             97576.13  Australia
# 4                Aeronautical engineer             60956.63    Germany
# ...                                ...                  ...        ...
# 29995  Psychotherapist, dance movement            142238.00      China
# 29996         Scientist, water quality            123107.50         UK
# 29997                     Web designer             97305.51      China
# 29998           Primary school teacher             95599.22     Brazil
# 29999                Company secretary             65679.61    Germany
#
#             Industry
# 0                 IT
# 1      Manufacturing
# 2            Finance
# 3         Healthcare
# ...

# %%
print(df.loc[10, 'Job Title'])
# Out:
# Emergency planning/management officer

# %%
print(df.iloc[10, 0])
# Out:
# Emergency planning/management officer

# %%
df.iloc[20, 5]              # Index-based access
# Out:
# 'High School'

# %%
df.query('`Median Salary (USD)` > 50000')         # Filter with condition
# Out:
#                              Job Title       Industry  Job Status  \
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# 6                  Surveyor, insurance  Manufacturing  Decreasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 1            Moderate            132298.57    Master’s Degree
# ...

# %%
df['Industry'].isin(['Manufacturing', 'Finance	'])      # Check if values are in list
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997     True
# 29998    False
# 29999    False
# Name: Industry, Length: 30000, dtype: bool

# %%
df['Location'].isin(['Australia	', 'Germany','Brazil'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998     True
# 29999     True
# Name: Location, Length: 30000, dtype: bool

# %% [markdown]
# #**Data Manipulation**

# %%
df.groupby('Median Salary (USD)').agg({'Automation Risk (%)': ['mean','sum']})  # Group and summarize
# Out:
#                     Automation Risk (%)
#                                    mean    sum
# Median Salary (USD)
# 30001.86                          94.48  94.48
# 30003.41                          67.85  67.85
# 30004.15                           0.76   0.76
# 30007.31                           8.59   8.59
# 30016.61                          77.59  77.59
# ...                                 ...    ...
# 149988.71                         35.45  35.45
# 149990.73                         79.99  79.99
# 149993.41                         79.99  79.99
# 149997.75                         45.86  45.86
# 149998.50                         72.45  72.45
#
# [29968 rows x 2 columns]

# %%
#df.merge(df2, on='key', how='left') 
# Join
#df2 = pd.read_csv('second_file.csv')  # Make sure the file exists
#df.merge(df2, on='key', how='left')

# %%
df.pivot_table(values='Median Salary (USD)', index='Automation Risk (%)')        # Pivot
# Out:
#                      Median Salary (USD)
# Automation Risk (%)
# 0.00                        97682.100000
# 0.01                        59191.580000
# 0.02                        89618.440000
# 0.03                       126269.675000
# 0.04                       131713.790000
# ...                                  ...
# 99.95                       72405.826667
# 99.96                       75356.598333
# 99.97                       93140.648000
# 99.98                       68481.092500
# 99.99                      127500.585000
#
# [9519 rows x 1 columns]

# %%
df.sort_values(['Median Salary (USD)', 'Automation Risk (%)'])                 # Sort
# Out:
#                                Job Title        Industry  Job Status  \
# 16550  Planning and development surveyor   Manufacturing  Increasing
# 24869                     Retail manager   Manufacturing  Decreasing
# 17144            Communications engineer      Healthcare  Increasing
# 29163                        Interpreter          Retail  Increasing
# 4463                        TEFL teacher  Transportation  Decreasing
# ...                                  ...             ...         ...
# 24229                     Retail manager         Finance  Decreasing
# 16073                    Mining engineer  Transportation  Increasing
# 27259                 Materials engineer         Finance  Increasing
# 15350                  Medical physicist  Transportation  Increasing
# 18476                      Retail banker   Manufacturing  Decreasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 16550             Low             30001.86    Master’s Degree
# ...

# %%
pd.melt(df, id_vars='Job Title', value_vars=['Median Salary (USD)', 'Experience Required (Years)']) # Melt
# Out:
#                              Job Title                     variable      value
# 0                   Investment analyst          Median Salary (USD)   42109.76
# 1                Journalist, newspaper          Median Salary (USD)  132298.57
# 2                    Financial planner          Median Salary (USD)  143279.19
# 3                      Legal secretary          Median Salary (USD)   97576.13
# 4                Aeronautical engineer          Median Salary (USD)   60956.63
# ...                                ...                          ...        ...
# 59995  Psychotherapist, dance movement  Experience Required (Years)      16.00
# 59996         Scientist, water quality  Experience Required (Years)      19.00
# 59997                     Web designer  Experience Required (Years)       0.00
# 59998           Primary school teacher  Experience Required (Years)      15.00
# 59999                Company secretary  Experience Required (Years)      15.00
#
# ...

# %%
df_numeric_squared = df.select_dtypes(include='number').apply(lambda x: x**2)

# %%
df_squared = df.apply(lambda x: x**2 if pd.api.types.is_numeric_dtype(x) else x)

# %% [markdown]
# #**Statistics**

# %%
df.describe()                                 # Summary
# Out:
#        Median Salary (USD)  Experience Required (Years)  Job Openings (2024)  \
# count         30000.000000                 30000.000000         30000.000000
# mean          90119.965639                    10.051433          5039.640833
# std           34412.013953                     6.060678          2861.009654
# min           30001.860000                     0.000000           100.000000
# 25%           60500.702500                     5.000000          2570.000000
# 50%           90274.115000                    10.000000          5034.000000
# 75%          119454.710000                    15.000000          7527.000000
# max          149998.500000                    20.000000         10000.000000
#
#        Projected Openings (2030)  Remote Work Ratio (%)  Automation Risk (%)  \
# count               30000.000000           30000.000000         30000.000000
# mean                 5074.218100              49.836431            50.154229
# ...

# %%
df.groupby('Industry')['Median Salary (USD)'].agg(['mean', 'median'])  # Stats by group
# Out:
#                         mean    median
# Industry
# Education       89665.728780  90004.10
# Entertainment   90131.000994  89782.68
# Finance         90510.599371  91493.46
# Healthcare      89494.073933  89105.94
# IT              90941.672551  91286.93
# Manufacturing   89880.034508  90289.56
# Retail          90903.677461  91206.44
# Transportation  89450.660172  89853.86

# %%
df.groupby('Job Title')['Median Salary (USD)'].agg(['mean', 'median']) # Stats by group
# Out:
#                                           mean      median
# Job Title
# Academic librarian                89397.371818   90108.940
# Accommodation manager             94391.856842   96632.305
# Accountant, chartered             94498.133333   98653.055
# Accountant, chartered certified   98073.801556   95430.160
# Accountant, chartered management  97836.064545  105578.100
# ...                                        ...         ...
# Water quality scientist           96130.882449   96947.190
# Web designer                      82047.753725   78420.760
# Wellsite geologist                94075.603438   89537.690
# Writer                            87595.647955   90773.020
# Youth worker                      85097.757115   78689.335
#
# [639 rows x 2 columns]

# %%
df['Median Salary (USD)'].value_counts(normalize=True)        # Percentages
# Out:
# Median Salary (USD)
# 117711.88    0.000067
# 49693.90     0.000067
# 33841.64     0.000067
# 119301.98    0.000067
# 109363.80    0.000067
#                ...
# 137794.70    0.000033
# 81025.52     0.000033
# 80859.25     0.000033
# 130613.32    0.000033
# 65679.61     0.000033
# Name: proportion, Length: 29968, dtype: float64

# %%
df.corr(numeric_only=True)  # Correlation
# Out:
#                              Median Salary (USD)  Experience Required (Years)  \
# Median Salary (USD)                     1.000000                     0.003302
# Experience Required (Years)             0.003302                     1.000000
# Job Openings (2024)                    -0.000803                    -0.001322
# Projected Openings (2030)              -0.000230                     0.002285
# Remote Work Ratio (%)                  -0.003844                     0.007859
# Automation Risk (%)                     0.007980                     0.006541
# Gender Diversity (%)                    0.011688                    -0.006006
# Bonus Salary                            1.000000                     0.003302
#
#                              Job Openings (2024)  Projected Openings (2030)  \
# Median Salary (USD)                    -0.000803                  -0.000230
# Experience Required (Years)            -0.001322                   0.002285
# ...

# %%
df[['Median Salary (USD)', 'Automation Risk (%)']].corr()
 # Correlation
# Out:
#                      Median Salary (USD)  Automation Risk (%)
# Median Salary (USD)              1.00000              0.00798
# Automation Risk (%)              0.00798              1.00000

# %%
df.cov(numeric_only=True)   # Covariance
# Out:
#                              Median Salary (USD)  Experience Required (Years)  \
# Median Salary (USD)                 1.184187e+09                   688.610232
# Experience Required (Years)         6.886102e+02                    36.731812
# Job Openings (2024)                -7.902375e+04                   -22.926524
# Projected Openings (2030)          -2.268233e+04                    39.706006
# Remote Work Ratio (%)              -3.831372e+03                     1.379710
# Automation Risk (%)                 7.896304e+03                     1.139897
# Gender Diversity (%)                6.947922e+03                    -0.628816
# Bonus Salary                        1.184187e+08                    68.861023
#
#                              Job Openings (2024)  Projected Openings (2030)  \
# Median Salary (USD)                -7.902375e+04              -2.268233e+04
# Experience Required (Years)        -2.292652e+01               3.970601e+01
# ...

# %%
  df[['Median Salary (USD)', 'Automation Risk (%)']].cov()
 # Covariance
# Out:
#                      Median Salary (USD)  Automation Risk (%)
# Median Salary (USD)         1.184187e+09          7896.304465
# Automation Risk (%)         7.896304e+03           826.843637

# %%
#df.quantile([0.05, 0.40, 0.60])
df.quantile([0.05, 0.40, 0.60], numeric_only=True)

 # Quartiles
# Out:
#       Median Salary (USD)  Experience Required (Years)  Job Openings (2024)  \
# 0.05            36040.114                          1.0               592.95
# 0.40            78550.798                          8.0              4032.60
# 0.60           102196.142                         12.0              6028.00
#
#       Projected Openings (2030)  Remote Work Ratio (%)  Automation Risk (%)  \
# 0.05                      583.0                 4.9095                5.200
# 0.40                     4093.0                40.0260               40.120
# 0.60                     6099.0                59.5400               60.034
#
#       Gender Diversity (%)  Bonus Salary
# 0.05                 23.07     3604.0114
# 0.40                 43.89     7855.0798
# 0.60                 55.94    10219.6142

# %% [markdown]
# #**Data Cleaning**

# %%
df.dropna(subset=['Gender Diversity (%)'], how='any')           # Drop missing
# Out:
#                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 0            Moderate             42109.76    Master’s Degree
# ...

# %%
df.fillna(method='ffill')                      # Fill forward
# Out:
# C:\Users\nks07\AppData\Local\Temp\ipykernel_19644\378364363.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')                      # Fill forward
#                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# ...

# %%
df.drop_duplicates(subset=['Gender Diversity (%)'])            # Remove duplicates
# Out:
#                       Job Title        Industry  Job Status AI Impact Level  \
# 0            Investment analyst              IT  Increasing        Moderate
# 1         Journalist, newspaper   Manufacturing  Increasing        Moderate
# 2             Financial planner         Finance  Increasing             Low
# 3               Legal secretary      Healthcare  Increasing            High
# 4         Aeronautical engineer              IT  Increasing             Low
# ...                         ...             ...         ...             ...
# 29419                     Actor              IT  Increasing             Low
# 29454             Administrator  Transportation  Increasing            High
# 29617        Investment analyst          Retail  Decreasing            High
# 29648    Financial risk analyst          Retail  Increasing        Moderate
# 29666  Scientist, water quality         Finance  Increasing        Moderate
#
# ...

# %%
df['Gender Diversity (%)'].replace({'old':'new'})               # Replace values
# Out:
# 0        44.63
# 1        66.39
# 2        41.13
# 3        65.76
# 4        72.57
#          ...
# 29995    65.90
# 29996    31.18
# 29997    26.07
# 29998    40.43
# 29999    21.75
# Name: Gender Diversity (%), Length: 30000, dtype: float64

# %%
df['Gender Diversity (%)'].astype('category')                   # Change type
# Out:
# 0        44.63
# 1        66.39
# 2        41.13
# 3        65.76
# 4        72.57
#          ...
# 29995    65.90
# 29996    31.18
# 29997    26.07
# 29998    40.43
# 29999    21.75
# Name: Gender Diversity (%), Length: 30000, dtype: category
# Categories (5965, float64): [20.00, 20.01, 20.02, 20.03, ..., 79.97, 79.98, 79.99, 80.00]

# %%
df.interpolate(method='linear')                # Fill missing smartly
# Out:
# C:\Users\nks07\AppData\Local\Temp\ipykernel_19644\994496228.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear')                # Fill missing smartly
#                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# ...

# %% [markdown]
# #**Time Series**

# %%
#df.resample('M')['Median Salary (USD)'].mean()

# %%
#df.resample('M').mean()                        # Monthly avg

# %%
#  df.rolling(window=11).mean()                    # Moving avg

# %%
df.shift(periods=1)                            # Shift rows

# %%
pd.date_range('2024', periods=12, freq='M')    # Create date range
# Out:
# C:\Users\nks07\AppData\Local\Temp\ipykernel_19644\2351217607.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range('2024', periods=12, freq='M')    # Create date range
# DatetimeIndex(['2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
# df.asfreq('D', method='ffill')                 # Fill missing dates

# %%
# df['date'].dt.strftime('%Y-%m-%d')             # Format dates

# %% [markdown]
# #** String Operations**

# %%
df['Job Title'].str.contains('pattern') # Check pattern
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998    False
# 29999    False
# Name: Job Title, Length: 30000, dtype: bool

# %%
df['Job Title'].str.extract('(\d+)')          # Extract digits
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\nks07\AppData\Local\Temp\ipykernel_19644\2400847998.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['Job Title'].str.extract('(\d+)')          # Extract digits
#          0
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 29995  NaN
# 29996  NaN
# 29997  NaN
# 29998  NaN
# 29999  NaN
#
# [30000 rows x 1 columns]

# %%
df['Job Title'].str.split('-').str[0]         # Split and get part
# Out:
# 0                     Investment analyst
# 1                  Journalist, newspaper
# 2                      Financial planner
# 3                        Legal secretary
# 4                  Aeronautical engineer
#                       ...
# 29995    Psychotherapist, dance movement
# 29996           Scientist, water quality
# 29997                       Web designer
# 29998             Primary school teacher
# 29999                  Company secretary
# Name: Job Title, Length: 30000, dtype: object

# %%
df['Job Title'].str.lower()                   # Lowercase
# Out:
# 0                     investment analyst
# 1                  journalist, newspaper
# 2                      financial planner
# 3                        legal secretary
# 4                  aeronautical engineer
#                       ...
# 29995    psychotherapist, dance movement
# 29996           scientist, water quality
# 29997                       web designer
# 29998             primary school teacher
# 29999                  company secretary
# Name: Job Title, Length: 30000, dtype: object

# %%
df['Job Title'].str.strip()                   # Remove spaces
# Out:
# 0                     Investment analyst
# 1                  Journalist, newspaper
# 2                      Financial planner
# 3                        Legal secretary
# 4                  Aeronautical engineer
#                       ...
# 29995    Psychotherapist, dance movement
# 29996           Scientist, water quality
# 29997                       Web designer
# 29998             Primary school teacher
# 29999                  Company secretary
# Name: Job Title, Length: 30000, dtype: object

# %%
df['Job Title'].str.replace('\s+', '')        # Remove all spaces
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\nks07\AppData\Local\Temp\ipykernel_19644\2170981413.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df['Job Title'].str.replace('\s+', '')        # Remove all spaces
# 0                     Investment analyst
# 1                  Journalist, newspaper
# 2                      Financial planner
# 3                        Legal secretary
# 4                  Aeronautical engineer
#                       ...
# 29995    Psychotherapist, dance movement
# 29996           Scientist, water quality
# 29997                       Web designer
# 29998             Primary school teacher
# 29999                  Company secretary
# Name: Job Title, Length: 30000, dtype: object

# %% [markdown]
# #**Advanced Features**

# %%
def add_salary_bonus(df):
    df['Bonus Salary'] = df['Median Salary (USD)'] * 0.1
    return df

df = df.pipe(add_salary_bonus)

# %%
#df.pipe(func)                                 # Chain operations

# %%
#df.eval('df1 + df2')                          # Evaluate expressions

# %%
df.copy(deep=True)                            # Deep copy
# Out:
#                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 0            Moderate             42109.76    Master’s Degree
# ...

# %%
df.select_dtypes(include='number')           # Select only numbers
# Out:
#        Median Salary (USD)  Experience Required (Years)  Job Openings (2024)  \
# 0                 42109.76                            5                 1515
# 1                132298.57                           15                 1243
# 2                143279.19                            4                 3338
# 3                 97576.13                           15                 7173
# 4                 60956.63                           13                 5944
# ...                    ...                          ...                  ...
# 29995            142238.00                           16                 7816
# 29996            123107.50                           19                 9358
# 29997             97305.51                            0                 9605
# 29998             95599.22                           15                 5481
# 29999             65679.61                           15                 4435
#
# ...

# %%
df.nlargest(5, 'Median Salary (USD)')                         # Top 5
# Out:
#                 Job Title        Industry  Job Status AI Impact Level  \
# 18476       Retail banker   Manufacturing  Decreasing        Moderate
# 15350   Medical physicist  Transportation  Increasing             Low
# 27259  Materials engineer         Finance  Increasing        Moderate
# 16073     Mining engineer  Transportation  Increasing        Moderate
# 24229      Retail manager         Finance  Decreasing        Moderate
#
#        Median Salary (USD) Required Education  Experience Required (Years)  \
# 18476            149998.50    Master’s Degree                            6
# 15350            149997.75                PhD                            8
# 27259            149993.41  Bachelor’s Degree                           17
# 16073            149990.73        High School                           14
# 24229            149988.71    Master’s Degree                           19
#
#        Job Openings (2024)  Projected Openings (2030)  Remote Work Ratio (%)  \
# ...

# %%
df.explode('Median Salary (USD)')                             # Expand lists to rows
# Out:
#                              Job Title       Industry  Job Status  \
# 0                   Investment analyst             IT  Increasing
# 1                Journalist, newspaper  Manufacturing  Increasing
# 2                    Financial planner        Finance  Increasing
# 3                      Legal secretary     Healthcare  Increasing
# 4                Aeronautical engineer             IT  Increasing
# ...                                ...            ...         ...
# 29995  Psychotherapist, dance movement      Education  Increasing
# 29996         Scientist, water quality             IT  Decreasing
# 29997                     Web designer  Manufacturing  Decreasing
# 29998           Primary school teacher  Entertainment  Increasing
# 29999                Company secretary      Education  Increasing
#
#       AI Impact Level  Median Salary (USD) Required Education  \
# 0            Moderate             42109.76    Master’s Degree
# ...

# %%
#**Data Export**

# %%
df.to_csv('ai_job_trends_dataset.csv', index=False)          # To CSV

# %%
df.to_excel('ai_job_trends_dataset.xlsx', sheet_name='Sheet1') # To Excel

# %%
df.to_parquet('ai_job_trends_dataset.parquet')               # Parquet file

# %%
df.to_json('ai_job_trends_dataset.json', orient='records')   # To JSON
